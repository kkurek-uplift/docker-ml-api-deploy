# %% [markdown]
# # Full Article is here:
# https://mlinproduction.com/docker-for-ml-part-4/

# %% [markdown]
# ![image.png](attachment:b0661824-ec1b-486c-a804-330b31e812d3.png)

# %% [markdown]
# ![image.png](attachment:7b6488c8-e8c3-4719-8dab-5805b6e1e129.png)

# %% [markdown]
# ![image.png](attachment:87ca2d0f-f150-4713-b7b1-f706d1ec742d.png)

# %% [markdown]
# ![image.png](attachment:206a237f-8177-432e-b57c-d10637f80610.png)

# %% [markdown]
# ![image.png](attachment:f6ea8890-1250-4014-8c7f-359be101f1e6.png)

# %% [markdown]
# ![image.png](attachment:c89abd65-f1fe-4a28-b078-be2436c09a9b.png)
